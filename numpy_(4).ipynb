# %% [markdown]
# <a href="https://colab.research.google.com/github/shen25550/Machine-Learning-Topics/blob/main/numpy_(4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

(train_x, train_y), _ = keras.datasets.mnist.load_data()
train_x = train_x / 255.0

idx = 6000
plt.imshow(train_x[idx], cmap="gray")
plt.axis("off")
plt.title(str(train_y[idx]))
plt.show()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

(train_x, train_y), _ = keras.datasets.mnist.load_data()
train_x = train_x / 255.0

lst = [1000, 2000, 3000, 4000]

plt.figure(figsize=(12,3))
for i, n in enumerate(lst):
    plt.subplot(1,4,i+1)
    plt.imshow(train_x[n], cmap="gray")
    plt.axis("off")
    plt.title(str(train_y[n]))
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Input(shape=(28,28)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Input(shape=(28,28)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.compile(
    optimizer=keras.optimizers.SGD(),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("compiled with SGD")
# Out:
# compiled with SGD

# %%
import tensorflow as tf
from tensorflow import keras

(train_x, train_y), (test_x, test_y) = keras.datasets.mnist.load_data()
train_x = train_x / 255.0
test_x = test_x / 255.0

def train(ep):
    m = keras.Sequential([
        keras.layers.Input(shape=(28,28)),
        keras.layers.Flatten(),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dense(10, activation="softmax")
    ])
    m.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    m.fit(train_x, train_y, epochs=ep, verbose=2)
    return m.evaluate(test_x, test_y, verbose=0)[1]

a = train(2)
b = train(5)

print("epoch2:", a)
print("epoch5:", b)
# Out:
# Epoch 1/2
# 1875/1875 - 7s - 4ms/step - accuracy: 0.9253 - loss: 0.2613
# Epoch 2/2
# 1875/1875 - 10s - 5ms/step - accuracy: 0.9661 - loss: 0.1138
# Epoch 1/5
# 1875/1875 - 8s - 4ms/step - accuracy: 0.9267 - loss: 0.2608
# Epoch 2/5
# 1875/1875 - 7s - 4ms/step - accuracy: 0.9653 - loss: 0.1173
# Epoch 3/5
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9754 - loss: 0.0803
# Epoch 4/5
# 1875/1875 - 7s - 4ms/step - accuracy: 0.9822 - loss: 0.0598
# Epoch 5/5
# 1875/1875 - 6s - 3ms/step - accuracy: 0.9854 - loss: 0.0468
# epoch2: 0.9700000286102295
# epoch5: 0.9767000079154968
